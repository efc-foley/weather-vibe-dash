# %% [markdown]
# ##Vibe Coding Using Anti-Gravity
#
# This tutorial will guide you through building a **"Weather & Climate Analytics Dashboard"** using **Google Antigravity** and **Streamlit**.
#
# We will use **Open-Meteo**, a completely free, no-key-required API for historical weather data.
#
# ---
#
# ### 🛠️ The Tech Stack
#
# * **IDE:** Google Antigravity (Agentic VS Code Fork)
# * **Language:** Anaconda Python (or any Python 3.12+)
# * **Framework:** Streamlit (for the "Vibe" UI)
# * **Data Source:** [Open-Meteo API](https://open-meteo.com/) (Free, No Key)
#
# ---
#
# ### 📸 Phase 1: Setup & Agent Management
#
# #### Step 1: Initialize the Workspace
#
# 1. Open **Google Antigravity**.
# 2. Click **"New Window"** or **"Open Folder"** and create a folder named `weather-vibe-dash`.
# 3. Locate the **Agent Manager** icon in the top right bar (or cmd/ctrl + E).
#
# #### Step 2: Configure the Agent
#
# Before typing a prompt, check your (bottom left) **Settings** —>  **Review Policy** at the bottom of the Agent Manager.
#
# * **Recommendation:** Set it to **"Agent Decides"** or **"Always Proceed"** for maximum speed. If set to "Request Review," you will have to approve every file creation, which kills the "vibe."
#
# ---
#
# ### 🤖 Phase 2: The "Vibe" Prompt (Building the Core)
#
# In the Agent Manager chat box, type the following high-context prompt. This uses the **"Product Manager"** persona to force the agent to plan before coding.
#
# > **Prompt:**
# > "I want to build a Python Streamlit dashboard called 'SkyCast Analytics'.
# > **Goal:** Compare historical temperature data between two cities using the Open-Meteo API (no API key needed).
# > **Features:**
# > 1. Two text inputs for 'City A' and 'City B'.
# > 2. A date range picker (default to last 30 days).
# > 3. A Line Chart comparing 'Max Daily Temperature' for both cities.
# > 4. A 'Data Table' tab showing the raw values.
# > **Tech Stack:** Streamlit, Pandas, Plotly Express, and Requests.
# > **Action:** Create `requirements.txt` and `app.py`. Install dependencies and run the app. Ensure the UI is 'Light Mode' friendly."
# >
# >
#
# #### 👁️ What happens next (The Antigravity UI)
#
# *Instead of just spitting out code, Antigravity will generate "Artifacts."*
#
# **Screenshot Representation: The Implementation Plan**
#
# ```markdown
# [AG] Agent Manager -----------------------------------------|
# |                                                           |
# | 🟢 PLAN GENERATED                                         |
# |                                                           |
# | 1. Project Setup                                          |
# |    [ ] Create virtual environment (venv)                  |
# |    [ ] Create requirements.txt (streamlit, pandas, etc)   |
# |                                                           |
# | 2. Core Logic (Open-Meteo Integration)                    |
# |    [ ] Write function `get_lat_long(city_name)`           |
# |    [ ] Write function `get_weather_data(lat, lon)`        |
# |                                                           |
# | 3. UI Implementation                                      |
# |    [ ] Build Sidebar for inputs                           |
# |    [ ] Implement Plotly chart                             |
# |                                                           |
# | [Button: Approve Plan]  [Button: Edit Plan]               |
# |-----------------------------------------------------------|
#
# ```
#
# * **Action:** Click **"Approve Plan"** (or just hit Enter if on "Always Proceed").
#
# ---
#
# ### 💻 Phase 3: Execution & Verification
#
# The agent will now take over your terminal. You will see it running commands like `pip install -r requirements.txt` automatically.
#
# #### The "Browser Artifact"
#
# Once the code is written, the Agent will run `streamlit run app.py`.
# **Crucially**, Antigravity will open a **Browser Preview** panel inside the IDE.
#
# **Screenshot Representation: Browser Preview**
#
# ```markdown
# [Browser Preview: localhost:8501] --------------------------|
# |  SkyCast Analytics                                     ≡  |
# |                                                           |
# |  [ Sidebar ]           [ Main Chart Area ]                |
# |  City A: [ London ]    Comparision: London vs Paris       |
# |  City B: [ Paris  ]    |                                  |
# |                        |   /^\      /---\                 |
# |  [ Date Range ]        |  /   \    /     \                |
# |                        | /     \--/       \               |
# |                        |__________________________        |
# |                                                           |
# |                        [Tab: Chart] [Tab: Raw Data]       |
# |-----------------------------------------------------------|
#
# ```
#
# **Common Issue:** The agent might get the Open-Meteo API URL format wrong (it requires Latitude/Longitude, not City Names directly).
# **The Fix:** If you see an error in the Browser Preview, do **not** fix the code manually.
# **Type in Agent Manager:** *"I see an error. You need to use a geocoding step first to convert City Name to Lat/Long. Use the `geocoding-api.open-meteo.com` endpoint for this."*
#
# ---
#
# ### 🎨 Phase 4: Styling & Polishing (The "Vibe" Check)
#
# Now that it works, make it look professional.
#
# > **Prompt:**
# > "The UI works, but it looks basic.
# > 1. Use `st.columns` to put the City Inputs side-by-side.
# > 2. Add 'metric cards' (st.metric) at the top showing the 'Average Temp' for the selected period for both cities.
# > 3. Use a custom color palette for the chart: Neon Blue for City A and Sunset Orange for City B."
# >
# >
#
# The Agent will edit `app.py` in real-time. You will see the Browser Preview refresh automatically.
#
# ---
#
# ### 🚀 Phase 5: Final Code Structure
#
# If you want to manually verify the code, your `app.py` should look somewhat like this (Antigravity should have generated this):

# %%
import streamlit as st
import pandas as pd
import requests
import plotly.express as px

# 1. Setup Page
st.set_page_config(page_title="SkyCast Analytics", layout="wide")

# 2. Helper Functions (The "Logic")
def get_coords(city_name):
    url = f"https://geocoding-api.open-meteo.com/v1/search?name={city_name}&count=1"
    response = requests.get(url).json()
    if "results" in response:
        return response["results"][0]["latitude"], response["results"][0]["longitude"]
    return None, None

def get_weather(lat, lon):
    # Fetching last 30 days of data
    url = f"https://archive-api.open-meteo.com/v1/archive?latitude={lat}&longitude={lon}&start_date=2025-12-01&end_date=2025-12-30&daily=temperature_2m_max&timezone=auto"
    return requests.get(url).json()

# 3. The UI Layout
st.title("⚡ SkyCast Analytics")

col1, col2 = st.columns(2)
with col1:
    city_a = st.text_input("City A", "New York")
with col2:
    city_b = st.text_input("City B", "Tokyo")

if st.button("Analyze Vibe"):
    # (Agent would insert complex data processing here)
    st.success("Data fetched successfully!")

# %% [markdown]
# ### 📦 Next Step for You
#
# Once the app is running in the Antigravity preview, you can deploy it to public using Streamlit Community Cloud:
#
# 1. Ask the agent to create git repository for you and show you how to deploy it to Streamlit Community Cloud.
# 2. Follow the instructions from the agent and you will need to setup a github account and link it to streamlit.
